# %% [markdown]
# # Nielsen ratings

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_cable = pd.read_csv("Nielsenratings_dataset.csv")

# %%
df_cable.head()
# Out:
#                      name channel                genre  season  episode  \
# 0  Dancing with the Stars     ABC  Reality-Competition      26        1
# 1  Dancing with the Stars     ABC  Reality-Competition      26        2
# 2  Dancing with the Stars     ABC  Reality-Competition      26        3
# 3  Dancing with the Stars     ABC  Reality-Competition      26        4
# 4  Dancing with the Stars     ABC  Reality-Competition      25        1
#
#      year     day  time  minutes  viewers  rating
# 0  2018-S  Monday  8:00      120     8.48     1.1
# 1  2018-S  Monday  8:00      120     7.73     1.0
# 2  2018-S  Monday  8:00      120     7.68     1.0
# 3  2018-S  Monday  8:00       60     8.77     1.1
# 4  2017-F  Monday  8:00      120    10.71     1.6

# %%
df_breakingbad = pd.read_csv("breaking-bad.csv")

# %%
df_breakingbad.head()
# Out:
#    season  episode                          title  year  votes  rating  \
# 0       1        1                          Pilot  2008  23970     9.0
# 1       1        2            Cat's in the Bag...  2008  17267     8.7
# 2       1        3  ...And the Bag's in the River  2008  16719     8.8
# 3       1        4                     Cancer Man  2008  16211     8.3
# 4       1        5                    Gray Matter  2008  15896     8.4
#
#    us-viewers
# 0        1.41
# 1        1.49
# 2        1.08
# 3        1.09
# 4        0.97

# %%
df_breakingbad = df_breakingbad.rename(columns={'title': 'name','us-viewers':'viewers'})

# %%
df_breakingbad.head()
# Out:
#    season  episode                           name  year  votes  rating  \
# 0       1        1                          Pilot  2008  23970     9.0
# 1       1        2            Cat's in the Bag...  2008  17267     8.7
# 2       1        3  ...And the Bag's in the River  2008  16719     8.8
# 3       1        4                     Cancer Man  2008  16211     8.3
# 4       1        5                    Gray Matter  2008  15896     8.4
#
#    viewers
# 0     1.41
# 1     1.49
# 2     1.08
# 3     1.09
# 4     0.97

# %%
# Replace all the values in the "name" column with "Breaking Bad"
df_breakingbad['name'] = 'Breaking Bad'

# %%
df_breakingbad.head(60)
# Out:
#     season  episode          name  year   votes  rating  viewers
# 0        1        1  Breaking Bad  2008   23970     9.0     1.41
# 1        1        2  Breaking Bad  2008   17267     8.7     1.49
# 2        1        3  Breaking Bad  2008   16719     8.8     1.08
# 3        1        4  Breaking Bad  2008   16211     8.3     1.09
# 4        1        5  Breaking Bad  2008   15896     8.4     0.97
# 5        1        6  Breaking Bad  2008   18447     9.3     1.07
# 6        1        7  Breaking Bad  2008   16208     8.9     1.50
# 7        2        1  Breaking Bad  2009   14506     8.7     1.66
# 8        2        2  Breaking Bad  2009   16918     9.3     1.60
# 9        2        3  Breaking Bad  2009   14062     8.4     1.13
# 10       2        4  Breaking Bad  2009   14193     8.3     1.29
# 11       2        5  Breaking Bad  2009   13761     8.4     1.21
# 12       2        6  Breaking Bad  2009   15225     8.9     1.41
# ...

# %%
df_the_office_series = pd.read_csv("the_office_series.csv")

# %%
df_the_office_series.head()
# Out:
#    Unnamed: 0  Season   EpisodeTitle  \
# 0           0       1          Pilot
# 1           1       1  Diversity Day
# 2           2       1    Health Care
# 3           3       1   The Alliance
# 4           4       1     Basketball
#
#                                                About  Ratings  Votes  \
# 0  The premiere episode introduces the boss and s...      7.5   4936
# 1  Michael's off color remark puts a sensitivity ...      8.3   4801
# 2  Michael leaves Dwight in charge of picking the...      7.8   4024
# 3  Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4  Michael and his staff challenge the warehouse ...      8.4   4294
#
#    Viewership  Duration            Date GuestStars         Director  \
# 0        11.2        23   24 March 2005        NaN       Ken Kwapis
# 1         6.0        23   29 March 2005        NaN       Ken Kwapis
# 2         5.8        22    5 April 2005        NaN  Ken Whittingham
# ...

# %%
df_the_office_series = df_the_office_series.rename(columns={'EpisodeTitle': 'name','Viewership':'viewers','Ratings': 'rating','Season':'season'})

# %%
df_the_office_series.head()
# Out:
#    Unnamed: 0  season           name  \
# 0           0       1          Pilot
# 1           1       1  Diversity Day
# 2           2       1    Health Care
# 3           3       1   The Alliance
# 4           4       1     Basketball
#
#                                                About  rating  Votes  viewers  \
# 0  The premiere episode introduces the boss and s...     7.5   4936     11.2
# 1  Michael's off color remark puts a sensitivity ...     8.3   4801      6.0
# 2  Michael leaves Dwight in charge of picking the...     7.8   4024      5.8
# 3  Just for a laugh, Jim agrees to an alliance wi...     8.1   3915      5.4
# 4  Michael and his staff challenge the warehouse ...     8.4   4294      5.0
#
#    Duration            Date GuestStars         Director  \
# 0        23   24 March 2005        NaN       Ken Kwapis
# 1        23   29 March 2005        NaN       Ken Kwapis
# 2        22    5 April 2005        NaN  Ken Whittingham
# ...

# %%
df_the_office_series['name'] = 'The office'

# %%
df_the_office_series.head()
# Out:
#    Unnamed: 0  season        name  \
# 0           0       1  The office
# 1           1       1  The office
# 2           2       1  The office
# 3           3       1  The office
# 4           4       1  The office
#
#                                                About  rating  Votes  viewers  \
# 0  The premiere episode introduces the boss and s...     7.5   4936     11.2
# 1  Michael's off color remark puts a sensitivity ...     8.3   4801      6.0
# 2  Michael leaves Dwight in charge of picking the...     7.8   4024      5.8
# 3  Just for a laugh, Jim agrees to an alliance wi...     8.1   3915      5.4
# 4  Michael and his staff challenge the warehouse ...     8.4   4294      5.0
#
#    Duration            Date GuestStars         Director  \
# 0        23   24 March 2005        NaN       Ken Kwapis
# 1        23   29 March 2005        NaN       Ken Kwapis
# 2        22    5 April 2005        NaN  Ken Whittingham
# 3        23   12 April 2005        NaN     Bryan Gordon
# ...

# %%
df_lucifer = pd.read_csv("lucifer_episodes_ratings.csv")

# %%
df_lucifer.head()
# Out:
#                               name  season  episode date_of_release  ratings  \
# 0                            Pilot       1        1      2017-09-01      8.8
# 1       Lucifer, Stay. Good Devil.       1        2      2016-02-01      8.2
# 2  The Would-Be Prince of Darkness       1        3      2016-02-08      8.2
# 3                   Manly Whatnots       1        4      2016-02-15      8.6
# 4                      Sweet Kicks       1        5      2016-02-22      8.1
#
#    reviews
# 0     8166
# 1     5517
# 2     4951
# 3     4879
# 4     4463

# %%
df_lucifer = df_lucifer.rename(columns={'date_of_release': 'year','ratings': 'rating'})

# %%
df_lucifer['name'] = 'lucifer'

# %%
df_lucifer.head()
# Out:
#       name  season  episode        year  rating  reviews
# 0  lucifer       1        1  2017-09-01     8.8     8166
# 1  lucifer       1        2  2016-02-01     8.2     5517
# 2  lucifer       1        3  2016-02-08     8.2     4951
# 3  lucifer       1        4  2016-02-15     8.6     4879
# 4  lucifer       1        5  2016-02-22     8.1     4463

# %%
df_brooklyn = pd.read_csv("brooklyn99_episodes.csv")

# %%
df_brooklyn.head(10)
# Out:
#    season  episode_num_in_season  episode_num_overall         title  \
# 0       1                      1                    1         Pilot
# 1       1                      2                    2    The Tagger
# 2       1                      3                    3     The Slump
# 3       1                      4                    4     M.E. Time
# 4       1                      5                    5   The Vulture
# 5       1                      6                    6     Halloween
# 6       1                      7                    7      48 Hours
# 7       1                      8                    8    Old School
# 8       1                      9                    9   Sal's Pizza
# 9       1                     10                   10  Thanksgiving
#
#                       directed_by                written_by original_air_date  \
# 0  Phil Lord & Christopher Miller  Dan Goor & Michael Schur        2013-09-17
# ...

# %%
df_brooklyn.shape
# Out:
# (153, 9)

# %%
df_brooklyn = df_brooklyn.rename(columns={'original_air_date': 'year','title': 'name','us_viewers': 'viewers','episode_num_overall':'episode'})

# %%
df_brooklyn['name'] = 'brooklyn 99'

# %%
df_brooklyn.head()
# Out:
#    season  episode_num_in_season  episode         name  \
# 0       1                      1        1  brooklyn 99
# 1       1                      2        2  brooklyn 99
# 2       1                      3        3  brooklyn 99
# 3       1                      4        4  brooklyn 99
# 4       1                      5        5  brooklyn 99
#
#                       directed_by                written_by        year  \
# 0  Phil Lord & Christopher Miller  Dan Goor & Michael Schur  2013-09-17
# 1                      Craig Zisk              Norm Hiscock  2013-09-24
# 2             Julie Anne Robinson            Prentice Penny  2013-10-01
# 3                     Troy Miller                 Gil Ozeri  2013-10-08
# 4                    Jason Ensler            Laura McCreary  2013-10-15
#
#    prod_code    viewers
# 0      101.0  6170000.0
# 1      102.0  4030000.0
# 2      105.0  3430000.0
# 3      106.0  3340000.0
# 4      104.0  3430000.0

# %%
df_bigbang = pd.read_csv("Big Bang Theory_IMDB.csv")

# %%
df_bigbang.shape
# Out:
# (281, 9)

# %%
df_bigbang.head()
# Out:
#    index  Unnamed: 0  Season  Episode Number  \
# 0      0           0       1               0
# 1      1           1       1               1
# 2      2           2       1               2
# 3      3           3       1               3
# 4      4           4       1               4
#
#                            Air date                      Title  Rating  \
# 0    \n            1 May 2006\n                  Unaired Pilot     6.7
# 1  \n            24 Sep. 2007\n                          Pilot     8.3
# 2   \n            1 Oct. 2007\n        The Big Bran Hypothesis     8.4
# 3   \n            8 Oct. 2007\n      The Fuzzy Boots Corollary     7.8
# 4  \n            15 Oct. 2007\n       The Luminous Fish Effect     8.2
#
#      Votes                                               Plot
# 0  (1,641)  \n    The first Pilot of what will become "The...
# 1  (4,737)  \n    A pair of socially awkward theoretical p...
# 2  (3,716)  \n    Penny is furious with Leonard and Sheldo...
# ...

# %%
df_bigbang = df_bigbang.rename(columns={'Air date': 'year','Title': 'name','Episode Number': 'episode','Rating': 'rating','Season': 'season'})

# %%
df_bigbang.head()
# Out:
#    index  Unnamed: 0  season  episode                              year  \
# 0      0           0       1        0    \n            1 May 2006\n
# 1      1           1       1        1  \n            24 Sep. 2007\n
# 2      2           2       1        2   \n            1 Oct. 2007\n
# 3      3           3       1        3   \n            8 Oct. 2007\n
# 4      4           4       1        4  \n            15 Oct. 2007\n
#
#                         name  rating    Votes  \
# 0              Unaired Pilot     6.7  (1,641)
# 1                      Pilot     8.3  (4,737)
# 2    The Big Bran Hypothesis     8.4  (3,716)
# 3  The Fuzzy Boots Corollary     7.8  (3,251)
# 4   The Luminous Fish Effect     8.2  (3,311)
#
#                                                 Plot
# 0  \n    The first Pilot of what will become "The...
# 1  \n    A pair of socially awkward theoretical p...
# 2  \n    Penny is furious with Leonard and Sheldo...
# 3  \n    Leonard gets upset when he discovers tha...
# ...

# %%
df_bigbang['name'] = 'big bang theory'

# %%
df_bigbang.head()
# Out:
#    index  Unnamed: 0  season  episode                              year  \
# 0      0           0       1        0    \n            1 May 2006\n
# 1      1           1       1        1  \n            24 Sep. 2007\n
# 2      2           2       1        2   \n            1 Oct. 2007\n
# 3      3           3       1        3   \n            8 Oct. 2007\n
# 4      4           4       1        4  \n            15 Oct. 2007\n
#
#               name  rating    Votes  \
# 0  big bang theory     6.7  (1,641)
# 1  big bang theory     8.3  (4,737)
# 2  big bang theory     8.4  (3,716)
# 3  big bang theory     7.8  (3,251)
# 4  big bang theory     8.2  (3,311)
#
#                                                 Plot
# 0  \n    The first Pilot of what will become "The...
# 1  \n    A pair of socially awkward theoretical p...
# 2  \n    Penny is furious with Leonard and Sheldo...
# 3  \n    Leonard gets upset when he discovers tha...
# 4  \n    Sheldon's mother is called to intervene ...

# %%
df_modrenfamily = pd.read_csv("modern_family_info.csv")

# %%
df_modrenfamily.head()
# Out:
#                Title     Airdate Season-Episode  Rating  Total Votes  \
# 0              Pilot  2009-09-23          S1-E1     8.2         3654
# 1  The Bicycle Thief  2009-09-30          S1-E2     8.1         3006
# 2   Come Fly with Me  2009-10-07          S1-E3     8.0         2650
# 3       The Incident  2009-10-14          S1-E4     8.2         2710
# 4        Coal Digger  2009-10-21          S1-E5     8.3         2606
#
#                                          Description  \
# 0  Jay must adapt to his young new wife, Gloria a...
# 1  After buying a new bike for his son, Phil ends...
# 2  Jay takes Phil on a model-airplane excursion w...
# 3  Jay's ex-wife shows up for the first time foll...
# 4  A conflict between Manny and Luke spreads to t...
#
#                                           Image Link
# 0  https://m.media-amazon.com/images/M/MV5BMTc4MT...
# 1  https://m.media-amazon.com/images/M/MV5BMTcwOT...
# 2  https://m.media-amazon.com/images/M/MV5BMjA0OT...
# ...

# %%
df_modrenfamily = df_modrenfamily.rename(columns={'Airdate': 'year','Title': 'name','Season-Episode	': 'episode','Rating': 'rating','Total Votes': 'votes'})

# %%
df_modrenfamily.head()
# Out:
#                 name        year Season-Episode  rating  votes  \
# 0              Pilot  2009-09-23          S1-E1     8.2   3654
# 1  The Bicycle Thief  2009-09-30          S1-E2     8.1   3006
# 2   Come Fly with Me  2009-10-07          S1-E3     8.0   2650
# 3       The Incident  2009-10-14          S1-E4     8.2   2710
# 4        Coal Digger  2009-10-21          S1-E5     8.3   2606
#
#                                          Description  \
# 0  Jay must adapt to his young new wife, Gloria a...
# 1  After buying a new bike for his son, Phil ends...
# 2  Jay takes Phil on a model-airplane excursion w...
# 3  Jay's ex-wife shows up for the first time foll...
# 4  A conflict between Manny and Luke spreads to t...
#
#                                           Image Link
# 0  https://m.media-amazon.com/images/M/MV5BMTc4MT...
# 1  https://m.media-amazon.com/images/M/MV5BMTcwOT...
# 2  https://m.media-amazon.com/images/M/MV5BMjA0OT...
# ...

# %%
df_modrenfamily = df_modrenfamily.rename(columns={'Season-Episode': 'episode'})

# %%
df_modrenfamily['name'] = 'modrenfamily'

# %%
df_modrenfamily.head()
# Out:
#            name        year episode  rating  votes  \
# 0  modrenfamily  2009-09-23   S1-E1     8.2   3654
# 1  modrenfamily  2009-09-30   S1-E2     8.1   3006
# 2  modrenfamily  2009-10-07   S1-E3     8.0   2650
# 3  modrenfamily  2009-10-14   S1-E4     8.2   2710
# 4  modrenfamily  2009-10-21   S1-E5     8.3   2606
#
#                                          Description  \
# 0  Jay must adapt to his young new wife, Gloria a...
# 1  After buying a new bike for his son, Phil ends...
# 2  Jay takes Phil on a model-airplane excursion w...
# 3  Jay's ex-wife shows up for the first time foll...
# 4  A conflict between Manny and Luke spreads to t...
#
#                                           Image Link
# 0  https://m.media-amazon.com/images/M/MV5BMTc4MT...
# 1  https://m.media-amazon.com/images/M/MV5BMTcwOT...
# 2  https://m.media-amazon.com/images/M/MV5BMjA0OT...
# 3  https://m.media-amazon.com/images/M/MV5BMTU1MT...
# 4  https://m.media-amazon.com/images/M/MV5BODgzMz...

# %%
df_modrenfamily.shape
# Out:
# (250, 7)

# %%
df_bettercallsaul = pd.read_csv("better_call_saul_episodes_IMDb_Ratings.csv")

# %%
df_bettercallsaul.head()
# Out:
#    season  episode_number                title     airdate  rating  \
# 0       1               1                  Uno  2017-10-04     8.5
# 1       1               2                 Mijo  2015-02-09     8.9
# 2       1               3                Nacho  2015-02-16     8.7
# 3       1               4                 Hero  2015-02-23     8.4
# 4       1               5  Alpine Shepherd Boy  2015-03-02     8.0
#
#    total_votes                                        description   episode
# 0        18386  Struggling public defender Jimmy McGill constr...  S1, Ep01
# 1        17409  Jimmy's latest scam has gone horribly wrong an...  S1, Ep02
# 2        14709  Jimmy must prove that Nacho is innocent when h...  S1, Ep03
# 3        13260  Jimmy makes a bold move against Hamlin in an e...  S1, Ep04
# 4        12759  After a strange encounter with the police, Chu...  S1, Ep05

# %%
df_bettercallsaul = df_bettercallsaul.rename(columns={'episode_number': 'episode','title': 'name','airdate': 'year','total_votes': 'votes'})

# %%
df_bettercallsaul['name'] = 'bettercallsaul'

# %%
df_bettercallsaul.head()
# Out:
#    season episode            name        year  rating  votes  \
# 0       1       1  bettercallsaul  2017-10-04     8.5  18386
# 1       1       2  bettercallsaul  2015-02-09     8.9  17409
# 2       1       3  bettercallsaul  2015-02-16     8.7  14709
# 3       1       4  bettercallsaul  2015-02-23     8.4  13260
# 4       1       5  bettercallsaul  2015-03-02     8.0  12759
#
#                                          description   episode
# 0  Struggling public defender Jimmy McGill constr...  S1, Ep01
# 1  Jimmy's latest scam has gone horribly wrong an...  S1, Ep02
# 2  Jimmy must prove that Nacho is innocent when h...  S1, Ep03
# 3  Jimmy makes a bold move against Hamlin in an e...  S1, Ep04
# 4  After a strange encounter with the police, Chu...  S1, Ep05

# %%
df_bettercallsaul.shape
# Out:
# (63, 8)

# %%
df_thewire = pd.read_csv("The_Wire.csv")

# %%
df_thewire.head()
# Out:
#    season  episode_number  total_episode_count episode_name    air_date  \
# 0       1               1                    1   The Target  2002-06-02
# 1       1               2                    2   The Detail  2002-06-09
# 2       1               3                    3     The Buys  2002-06-16
# 3       1               4                    4    Old Cases  2002-06-23
# 4       1               5                    5    The Pager  2002-06-30
#
#         director           story_writers teleplay_writers  \
# 0  Clark Johnson  David Simon & Ed Burns      David Simon
# 1  Clark Johnson  David Simon & Ed Burns      David Simon
# 2    Peter Medak  David Simon & Ed Burns      David Simon
# 3  Clement Virgo  David Simon & Ed Burns      David Simon
# 4  Clark Johnson  David Simon & Ed Burns         Ed Burns
#
#                                          description  viewers  total_votes  \
# 0  Baltimore Det. Jimmy McNulty finds himself in ...     3.70         6766
# ...

# %%
df_thewire = df_thewire.rename(columns={'episode_number': 'episode','episode_name': 'name','air_date': 'year','total_votes': 'votes'})

# %%
df_thewire['name'] = 'thewire'

# %%
df_thewire.head()
# Out:
#    season  episode  total_episode_count     name        year       director  \
# 0       1        1                    1  thewire  2002-06-02  Clark Johnson
# 1       1        2                    2  thewire  2002-06-09  Clark Johnson
# 2       1        3                    3  thewire  2002-06-16    Peter Medak
# 3       1        4                    4  thewire  2002-06-23  Clement Virgo
# 4       1        5                    5  thewire  2002-06-30  Clark Johnson
#
#             story_writers teleplay_writers  \
# 0  David Simon & Ed Burns      David Simon
# 1  David Simon & Ed Burns      David Simon
# 2  David Simon & Ed Burns      David Simon
# 3  David Simon & Ed Burns      David Simon
# 4  David Simon & Ed Burns         Ed Burns
#
#                                          description  viewers  votes  rating
# 0  Baltimore Det. Jimmy McNulty finds himself in ...     3.70   6766     7.9
# 1  Lt. Daniels puts his team together but the ext...     2.80   5518     8.2
# ...

# %%
df_thewire = df_thewire.drop(columns=['total_episode_count'])

# %%
df_thewire.head()
# Out:
#    season  episode     name        year       director  \
# 0       1        1  thewire  2002-06-02  Clark Johnson
# 1       1        2  thewire  2002-06-09  Clark Johnson
# 2       1        3  thewire  2002-06-16    Peter Medak
# 3       1        4  thewire  2002-06-23  Clement Virgo
# 4       1        5  thewire  2002-06-30  Clark Johnson
#
#             story_writers teleplay_writers  \
# 0  David Simon & Ed Burns      David Simon
# 1  David Simon & Ed Burns      David Simon
# 2  David Simon & Ed Burns      David Simon
# 3  David Simon & Ed Burns      David Simon
# 4  David Simon & Ed Burns         Ed Burns
#
#                                          description  viewers  votes  rating
# 0  Baltimore Det. Jimmy McNulty finds himself in ...     3.70   6766     7.9
# 1  Lt. Daniels puts his team together but the ext...     2.80   5518     8.2
# 2  After two weeks on the job, the team still doe...      NaN   5179     8.2
# ...

# %%
df_thebachelor = pd.read_csv("Thebachelor.csv")

# %%
df_thebachelor.head()
# Out:
#            Show  Season  No Overall  No in Season     Title        Air Date  \
# 0  The Bachelor       1           1             1  "Week 1"  March 25, 2002
# 1  The Bachelor       1           2             2  "Week 2"   April 1, 2002
# 2  The Bachelor       1           3             3  "Week 3"   April 8, 2002
# 3  The Bachelor       1           4             4  "Week 4"  April 15, 2002
# 4  The Bachelor       1           5             5  "Week 5"  April 22, 2002
#
#   Prod Code  US. Viewers (millions) Rating / Share (18-49)
# 0       101                     9.9                  4.0/0
# 1       102                    10.2                 4.4/11
# 2       103                     9.4                 4.2/10
# 3       104                    11.1                 4.6/12
# 4       105                    13.1                 5.7/14

# %%
df_thebachelor = df_thebachelor.rename(columns={'Season': 'season','Title': 'name','Air Date': 'year','No Overall': 'episode','US. Viewers (millions)': 'viewers','Rating / Share (18-49)': 'rating',})

# %%
df_thebachelor['name'] = 'thebachelor'

# %%
df_thebachelor.head(60)
# Out:
#             Show  season  episode  No in Season         name  \
# 0   The Bachelor       1        1             1  thebachelor
# 1   The Bachelor       1        2             2  thebachelor
# 2   The Bachelor       1        3             3  thebachelor
# 3   The Bachelor       1        4             4  thebachelor
# 4   The Bachelor       1        5             5  thebachelor
# 5   The Bachelor       1        6             6  thebachelor
# 6   The Bachelor       1        7             7  thebachelor
# 7   The Bachelor       2        8             1  thebachelor
# 8   The Bachelor       2        9             2  thebachelor
# 9   The Bachelor       2       10             3  thebachelor
# 10  The Bachelor       2       11             4  thebachelor
# 11  The Bachelor       2       12             5  thebachelor
# 12  The Bachelor       2       13             6  thebachelor
# 13  The Bachelor       2       14             7  thebachelor
# ...

# %%
df_scrubs = pd.read_csv("scrubs_episodes.csv")

# %%
df_scrubs.head(6)
# Out:
#    season  episode_num_in_season  episode_num_overall  \
# 0       1                      1                    1
# 1       1                      2                    2
# 2       1                      3                    3
# 3       1                      4                    4
# 4       1                      5                    5
# 5       1                      6                    6
#
#                       title     directed_by                      written_by  \
# 0              My First Day  Adam Bernstein                   Bill Lawrence
# 1                 My Mentor  Adam Bernstein                   Bill Lawrence
# 2  My Best Friend's Mistake  Adam Bernstein                   Eric Weinberg
# 3               My Old Lady   Marc Buckland                     Matt Tarses
# 4               My Two Dads      Craig Zisk  Neil Goldman & Garrett Donovan
# 5                    My Bad   Marc Buckland                 Gabrielle Allan
#
#   original_air_date prod_code  us_viewers
# ...

# %%
df_scrubs = df_scrubs.rename(columns={'Season': 'season','title': 'name','original_air_date': 'year', 'us_viewers': 'viewers','episode_num_in_season':'episode'})

# %%
df_scrubs['name'] = 'scrubs'

# %%
df_scrubs.head(60)
# Out:
#     season  episode  episode_num_overall    name        directed_by  \
# 0        1        1                    1  scrubs     Adam Bernstein
# 1        1        2                    2  scrubs     Adam Bernstein
# 2        1        3                    3  scrubs     Adam Bernstein
# 3        1        4                    4  scrubs      Marc Buckland
# 4        1        5                    5  scrubs         Craig Zisk
# 5        1        6                    6  scrubs      Marc Buckland
# 6        1        7                    7  scrubs        Peter Lauer
# 7        1        8                    8  scrubs  Lawrence Trilling
# 8        1        9                    9  scrubs       Elodie Keene
# 9        1       10                   10  scrubs    Matthew Diamond
# 10       1       11                   11  scrubs        Jeff Melman
# 11       1       12                   12  scrubs      Marc Buckland
# 12       1       13                   13  scrubs    Michael Spiller
# ...

# %%
df_himym_episodes = pd.read_csv("himym_episodes.csv")

# %%
df_himym_episodes.head()
# Out:
#    season  episode_num_in_season  episode_num_overall  \
# 0       1                      1                    1
# 1       1                      2                    2
# 2       1                      3                    3
# 3       1                      4                    4
# 4       1                      5                    5
#
#                         title    directed_by                  written_by  \
# 0                       Pilot  Pamela Fryman  Carter Bays & Craig Thomas
# 1              Purple Giraffe  Pamela Fryman  Carter Bays & Craig Thomas
# 2  The Sweet Taste of Liberty  Pamela Fryman    Phil Lord & Chris Miller
# 3         Return of the Shirt  Pamela Fryman               Kourtney Kang
# 4                Okay Awesome  Pamela Fryman                Chris Harris
#
#   original_air_date prod_code  us_viewers
# 0        2005-09-19    1ALH79  10940000.0
# 1        2005-09-26    1ALH01  10400000.0
# 2        2005-10-03    1ALH02  10440000.0
# ...

# %%
df_himym_episodes = df_himym_episodes.rename(columns={'Season': 'season','title': 'name','original_air_date': 'year','episode_num_in_season': 'episode','us_viewers': 'viewers'})

# %%
df_himym_episodes['name'] = 'How I Met Your Mother'

# %%
df_himym_episodes.head()
# Out:
#    season  episode  episode_num_overall                   name    directed_by  \
# 0       1        1                    1  How I Met Your Mother  Pamela Fryman
# 1       1        2                    2  How I Met Your Mother  Pamela Fryman
# 2       1        3                    3  How I Met Your Mother  Pamela Fryman
# 3       1        4                    4  How I Met Your Mother  Pamela Fryman
# 4       1        5                    5  How I Met Your Mother  Pamela Fryman
#
#                    written_by        year prod_code     viewers
# 0  Carter Bays & Craig Thomas  2005-09-19    1ALH79  10940000.0
# 1  Carter Bays & Craig Thomas  2005-09-26    1ALH01  10400000.0
# 2    Phil Lord & Chris Miller  2005-10-03    1ALH02  10440000.0
# 3               Kourtney Kang  2005-10-10    1ALH03   9840000.0
# 4                Chris Harris  2005-10-17    1ALH04  10140000.0

# %%
df_strangerthings = pd.read_csv("Stranger_Things_Ratings.csv")

# %%
df_strangerthings.head(60)
# Out:
#     index  Episode_Number                                             Title  \
# 0       0               1          Chapter One: The Vanishing of Will Byers
# 1       1               2           Chapter Two: The Weirdo on Maple Street
# 2       2               3                        Chapter Three: Holly Jolly
# 3       3               4                            Chapter Four: The Body
# 4       4               5            Chapter Five: The Flea and the Acrobat
# 5       5               6                          Chapter Six: The Monster
# 6       6               7                        Chapter Seven: The Bathtub
# 7       7               8                    Chapter Eight: The Upside Down
# 8       8               9                               Chapter One: MADMAX
# 9       9              10                 Chapter Two: Trick or Treat Freak
# 10     10              11                       Chapter Three: The Pollywog
# ...

# %%
df_strangerthings = df_strangerthings.rename(columns={' Title': 'name',' Year': 'year','Episode_Number': 'episode',' Rating': 'rating'})

# %%
df_strangerthings.head()
# Out:
#    index  episode                                      name  \
# 0      0        1  Chapter One: The Vanishing of Will Byers
# 1      1        2   Chapter Two: The Weirdo on Maple Street
# 2      2        3                Chapter Three: Holly Jolly
# 3      3        4                    Chapter Four: The Body
# 4      4        5    Chapter Five: The Flea and the Acrobat
#
#                                            Image_url  year  \
# 0  https://m.mediaamazon.com/images/M/MV5BMTUwNTE...  2016
# 1  https://m.mediaamazon.com/images/M/MV5BMjA4NzA...  2016
# 2  https://m.mediaamazon.com/images/M/MV5BOTkyMDQ...  2016
# 3  https://m.mediaamazon.com/images/M/MV5BMTkwMjU...  2016
# 4  https://m.mediaamazon.com/images/M/MV5BMjM0NjQ...  2016
#
#                                          Description  \
# 0  At the U.S. Dept. of Energy an unexplained eve...
# 1  Mike hides the mysterious girl in his house. J...
# 2  An increasingly concerned Nancy looks for Barb...
# ...

# %%
# create a mapping between year and season
year_to_season = {2016: 1, 2017: 2, 2019: 3}

# create a new column 'season' based on the year_to_season mapping
df_strangerthings['season'] = df_strangerthings['year'].map(year_to_season)

# display the updated dataframe
print(df_strangerthings)
# Out:
#     index  episode                                              name  \
# 0       0        1          Chapter One: The Vanishing of Will Byers
# 1       1        2           Chapter Two: The Weirdo on Maple Street
# 2       2        3                        Chapter Three: Holly Jolly
# 3       3        4                            Chapter Four: The Body
# 4       4        5            Chapter Five: The Flea and the Acrobat
# 5       5        6                          Chapter Six: The Monster
# 6       6        7                        Chapter Seven: The Bathtub
# 7       7        8                    Chapter Eight: The Upside Down
# 8       8        9                               Chapter One: MADMAX
# 9       9       10                 Chapter Two: Trick or Treat Freak
# 10     10       11                       Chapter Three: The Pollywog
# 11     11       12                       Chapter Four: Will the Wise
# 12     12       13                             Chapter Five: Dig Dug
# ...

# %%
df_strangerthings['name'] = 'stranger things'

# %%
df_strangerthings.head(60)
# Out:
#     index  episode             name  \
# 0       0        1  stranger things
# 1       1        2  stranger things
# 2       2        3  stranger things
# 3       3        4  stranger things
# 4       4        5  stranger things
# 5       5        6  stranger things
# 6       6        7  stranger things
# 7       7        8  stranger things
# 8       8        9  stranger things
# 9       9       10  stranger things
# 10     10       11  stranger things
# 11     11       12  stranger things
# 12     12       13  stranger things
# 13     13       14  stranger things
# 14     14       15  stranger things
# 15     15       16  stranger things
# 16     16       17  stranger things
# 17     17       18  stranger things
# 18     18       19  stranger things
# 19     19       20  stranger things
# 20     20       21  stranger things
# 21     21       22  stranger things
# 22     22       23  stranger things
# 23     23       24  stranger things
# 24     24       25  stranger things
#
# ...

# %%
df_simpsons_episodes = pd.read_csv("simpsons_episodes.csv")

# %%
df_simpsons_episodes.head()
# Out:
#    id                              title  \
# 0   0  Simpsons Roasting on an Open Fire
# 1   1                    Bart the Genius
# 2   2                    Homer's Odyssey
# 3   3      There's No Disgrace Like Home
# 4   4                   Bart the General
#
#                                          description original_air_date  \
# 0  Homer is forced to become a department store S...        1989-12-17
# 1  Bart ends up at a school for gifted children a...        1990-01-14
# 2  After losing his job, Homer contemplates endin...        1990-01-21
# 3  After being embarrassed by the rest of the fam...        1990-01-28
# 4  After being beaten up by Nelson Muntz one too ...        1990-02-04
#
#   production_code                     directed_by  \
# 0            7G08                 David Silverman
# 1            7G02                 David Silverman
# 2            7G03                      Wes Archer
# 3            7G04  Gregg Vanzo & Kent Butterworth
# ...

# %%
df_simpsons_episodes = df_simpsons_episodes.rename(columns={'title': 'name','original_air_date': 'year','number_in_season': 'episode','imdb_rating': 'rating','us_viewers_in_millions': 'viewers'})

# %%
df_simpsons_episodes['name'] = 'The Simpsons'

# %%
df_simpsons_episodes.head()
# Out:
#    id          name                                        description  \
# 0   0  The Simpsons  Homer is forced to become a department store S...
# 1   1  The Simpsons  Bart ends up at a school for gifted children a...
# 2   2  The Simpsons  After losing his job, Homer contemplates endin...
# 3   3  The Simpsons  After being embarrassed by the rest of the fam...
# 4   4  The Simpsons  After being beaten up by Nelson Muntz one too ...
#
#          year production_code                     directed_by  \
# 0  1989-12-17            7G08                 David Silverman
# 1  1990-01-14            7G02                 David Silverman
# 2  1990-01-21            7G03                      Wes Archer
# 3  1990-01-28            7G04  Gregg Vanzo & Kent Butterworth
# 4  1990-02-04            7G05                 David Silverman
#
#                        written_by  season  episode  number_in_series viewers  \
# 0                       Mimi Pond       1        1                 1    26.7
# ...

# %%
df_Game_of_Thrones = pd.read_csv("Game_of_Thrones.csv")

# %%
df_Game_of_Thrones.head()
# Out:
#    Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0       1                        1                         1
# 1       1                        2                         2
# 2       1                        3                         3
# 3       1                        4                         4
# 4       1                        5                         5
#
#                     Title of the Episode  Running Time (Minutes)  \
# 0                       Winter Is Coming                      61
# 1                          The Kingsroad                      55
# 2                              Lord Snow                      57
# 3  Cripples, Bastards, and Broken Things                      55
# 4                  The Wolf and the Lion                      54
#
#       Directed by                  Written by Original Air Date  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss       17-Apr-2011
# 1  Tim Van Patten  David Benioff, D. B. Weiss       24-Apr-2011
# ...

# %%
df_Game_of_Thrones = df_Game_of_Thrones.rename(columns={'Title of the Episode': 'name','Original Air Date': 'year','No. of Episode (Overall)': 'episode','IMDb Rating': 'rating','U.S. Viewers (Millions)': 'viewers','Season':'season','Running Time (Minutes)':'minutes'})

# %%
df_Game_of_Thrones['name'] = 'Game of Thrones'

# %%
df_Game_of_Thrones.head()
# Out:
#    season  No. of Episode (Season)  episode             name  minutes  \
# 0       1                        1        1  Game of Thrones       61
# 1       1                        2        2  Game of Thrones       55
# 2       1                        3        3  Game of Thrones       57
# 3       1                        4        4  Game of Thrones       55
# 4       1                        5        5  Game of Thrones       54
#
#       Directed by                  Written by         year  viewers  \
# 0  Tim Van Patten  David Benioff, D. B. Weiss  17-Apr-2011     2.22
# 1  Tim Van Patten  David Benioff, D. B. Weiss  24-Apr-2011     2.20
# 2      Brian Kirk  David Benioff, D. B. Weiss   1-May-2011     2.44
# 3      Brian Kirk                Bryan Cogman   8-May-2011     2.45
# 4      Brian Kirk  David Benioff, D. B. Weiss  15-May-2011     2.58
#
#         Music by Cinematography by         Editing by  rating  \
# 0  Ramin Djawadi     Alik Sakharov  Oral Norrie Ottey     8.9
# ...

# %%
df_friends_episodes = pd.read_csv("friends_episodes_v3.csv", encoding='iso-8859-1')

# %%
df_friends_episodes.head()
# Out:
#    Year_of_prod  Season  Episode Number  \
# 0          1994       1               1
# 1          1994       1               2
# 2          1994       1               3
# 3          1994       1               4
# 4          1994       1               5
#
#                                      Episode_Title  Duration  \
# 0  The One Where Monica Gets a Roommate: The Pilot        22
# 1             The One with the Sonogram at the End        22
# 2                           The One with the Thumb        22
# 3               The One with George Stephanopoulos        22
# 4   The One with the East German Laundry Detergent        22
#
#                                              Summary       Director  Stars  \
# 0  Monica and the gang introduce Rachel to the "r...  James Burrows    8.3
# 1  Ross finds out his ex-wife is pregnant. Rachel...  James Burrows    8.1
# 2  Monica becomes irritated when everyone likes h...  James Burrows    8.2
# ...

# %%
df_friends_episodes = df_friends_episodes.rename(columns={'Episode_Title': 'name','Year_of_prod': 'year','Episode Number': 'episode','Stars': 'rating','Season':'season'})

# %%
df_friends_episodes['name'] = 'friends'

# %%
df_friends_episodes.head()
# Out:
#    year  season  episode     name  Duration  \
# 0  1994       1        1  friends        22
# 1  1994       1        2  friends        22
# 2  1994       1        3  friends        22
# 3  1994       1        4  friends        22
# 4  1994       1        5  friends        22
#
#                                              Summary       Director  rating  \
# 0  Monica and the gang introduce Rachel to the "r...  James Burrows     8.3
# 1  Ross finds out his ex-wife is pregnant. Rachel...  James Burrows     8.1
# 2  Monica becomes irritated when everyone likes h...  James Burrows     8.2
# 3  Joey and Chandler take Ross to a hockey game t...  James Burrows     8.1
# 4  Eager to spend time with Rachel, Ross pretends...  Pamela Fryman     8.5
#
#    Votes
# 0   7440
# 1   4888
# 2   4605
# 3   4468
# 4   4438

# %%
df_walking_dead = pd.read_csv("Thw_walkingdaed.csv", encoding='iso-8859-1')

# %%
df_walking_dead.head()
# Out:
#    Season  Episode  Episode(overall)                 Title  \
# 0       1        1                 1         Days Gone Bye
# 1       1        2                 2                  Guts
# 2       1        3                 3  Tell It to the Frogs
# 3       1        4                 4                 Vatos
# 4       1        5                 5              Wildfire
#
#              Directed by                                         Written by  \
# 0         Frank Darabont                        Teleplay by: Frank Darabont
# 1      Michelle MacLaren                                     Frank Darabont
# 2  Gwyneth Horder-Payton  Story by: Charles H. Eglee & Jack LoGiudice & ...
# 3            Johan Renck                                     Robert Kirkman
# 4       Ernest Dickerson                                       Glen Mazzara
#
#   Original Air date  US viewers(millions)
# 0        10/31/2010                  5.35
# 1         11/7/2010                  4.71
# ...

# %%
df_walking_dead = df_walking_dead.rename(columns={'Title': 'name','Original Air date': 'year','Episode': 'episode','US viewers(millions)': 'viewers','Season':'season'})

# %%
df_walking_dead['name'] = 'The walking dead'

# %%
df_walking_dead.head()
# Out:
#    season  episode  Episode(overall)              name            Directed by  \
# 0       1        1                 1  The walking dead         Frank Darabont
# 1       1        2                 2  The walking dead      Michelle MacLaren
# 2       1        3                 3  The walking dead  Gwyneth Horder-Payton
# 3       1        4                 4  The walking dead            Johan Renck
# 4       1        5                 5  The walking dead       Ernest Dickerson
#
#                                           Written by        year  viewers
# 0                        Teleplay by: Frank Darabont  10/31/2010     5.35
# 1                                     Frank Darabont   11/7/2010     4.71
# 2  Story by: Charles H. Eglee & Jack LoGiudice & ...  11/14/2010     5.07
# 3                                     Robert Kirkman  11/21/2010     4.75
# 4                                       Glen Mazzara  11/28/2010     5.56

# %% [markdown]
# # Merging all the datframes together

# %%
# concatenate the two dataframes
df_combined_Tvshows = pd.concat([df_walking_dead, df_friends_episodes,df_Game_of_Thrones,df_simpsons_episodes,df_strangerthings,df_himym_episodes,df_scrubs,df_thebachelor,df_thewire,df_modrenfamily,df_bigbang,df_brooklyn,df_lucifer,df_the_office_series,df_breakingbad,df_cable], ignore_index=True)

# %%
df_combined_Tvshows.head(1000)
# Out:
#      season episode  Episode(overall)              name  \
# 0       1.0       1               1.0  The walking dead
# 1       1.0       2               2.0  The walking dead
# 2       1.0       3               3.0  The walking dead
# 3       1.0       4               4.0  The walking dead
# 4       1.0       5               5.0  The walking dead
# ..      ...     ...               ...               ...
# 995    24.0      10               NaN      The Simpsons
# 996    24.0      11               NaN      The Simpsons
# 997    24.0      12               NaN      The Simpsons
# 998    24.0      13               NaN      The Simpsons
# 999    24.0      14               NaN      The Simpsons
#
#                Directed by                                         Written by  \
# 0           Frank Darabont                        Teleplay by: Frank Darabont
# 1        Michelle MacLaren                                     Frank Darabont
# ...

# %%
df_combined_Tvshows.shape
# Out:
# (5604, 58)

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['Episode(overall)','Directed by','Written by','Duration','Summary','reviews','episode_num_in_season','About','Date','channel','genre','time'])

# %%
df_combined_Tvshows.head()
# Out:
#    season episode              name        year viewers Director rating Votes  \
# 0     1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN   NaN
# 1     1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN   NaN
# 2     1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN   NaN
# 3     1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN   NaN
# 4     1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN   NaN
#
#    No. of Episode (Season)  minutes  ... story_writers teleplay_writers votes  \
# 0                      NaN      NaN  ...           NaN              NaN   NaN
# 1                      NaN      NaN  ...           NaN              NaN   NaN
# 2                      NaN      NaN  ...           NaN              NaN   NaN
# 3                      NaN      NaN  ...           NaN              NaN   NaN
# 4                      NaN      NaN  ...           NaN              NaN   NaN
#
# ...

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['No. of Episode (Season)','story_writers','teleplay_writers','Description','Image Link','Unnamed: 0','Plot','GuestStars','Writers','day'])

# %%
df_combined_Tvshows.head()
# Out:
#    season episode              name        year viewers Director rating Votes  \
# 0     1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN   NaN
# 1     1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN   NaN
# 2     1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN   NaN
# 3     1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN   NaN
# 4     1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN   NaN
#
#    minutes Music by  ...  Description  Genre   Runtime  episode_num_overall  \
# 0      NaN      NaN  ...          NaN    NaN       NaN                  NaN
# 1      NaN      NaN  ...          NaN    NaN       NaN                  NaN
# 2      NaN      NaN  ...          NaN    NaN       NaN                  NaN
# 3      NaN      NaN  ...          NaN    NaN       NaN                  NaN
# 4      NaN      NaN  ...          NaN    NaN       NaN                  NaN
#
# ...

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['Music by','prod_code','episode_num_overall','No in Season','Prod Code','director','Show','votes'])

# %%
df_combined_Tvshows.head()
# Out:
#    season episode              name        year viewers Director rating Votes  \
# 0     1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN   NaN
# 1     1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN   NaN
# 2     1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN   NaN
# 3     1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN   NaN
# 4     1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN   NaN
#
#    minutes Cinematography by  ... description  production_code  directed_by  \
# 0      NaN               NaN  ...         NaN              NaN          NaN
# 1      NaN               NaN  ...         NaN              NaN          NaN
# 2      NaN               NaN  ...         NaN              NaN          NaN
# 3      NaN               NaN  ...         NaN              NaN          NaN
# 4      NaN               NaN  ...         NaN              NaN          NaN
#
# ...

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['Cinematography by','description','production_code','directed_by','written_by','number_in_series','index'])

# %%
df_combined_Tvshows
# Out:
#       season episode              name        year viewers Director rating  \
# 0        1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN
# 1        1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN
# 2        1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN
# 3        1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN
# 4        1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN
# ...      ...     ...               ...         ...     ...      ...    ...
# 5599     2.0      19   Madam Secretary      2016-S    9.86      NaN    1.1
# 5600     2.0      20   Madam Secretary      2016-S    9.57      NaN    0.9
# 5601     2.0      21   Madam Secretary      2016-S    9.57      NaN    1.0
# 5602     2.0      22   Madam Secretary      2016-S     9.9      NaN    1.0
# 5603     2.0      23   Madam Secretary      2016-S    9.99      NaN    1.0
#
#      Votes  minutes Editing by  ...  Metacritic Ratings  Ordered  \
# ...

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['Editing by','Metacritic Ratings','Ordered','Filming Duration','Novel(s) Adapted','Synopsis','id'])

# %%
df_combined_Tvshows.head()
# Out:
#    season episode              name        year viewers Director rating Votes  \
# 0     1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN   NaN
# 1     1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN   NaN
# 2     1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN   NaN
# 3     1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN   NaN
# 4     1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN   NaN
#
#    minutes  Rotten Tomatoes Rating (Percentage)  Image_url  Description  \
# 0      NaN                                  NaN        NaN          NaN
# 1      NaN                                  NaN        NaN          NaN
# 2      NaN                                  NaN        NaN          NaN
# 3      NaN                                  NaN        NaN          NaN
# 4      NaN                                  NaN        NaN          NaN
#
#    Genre  Runtime
# 0    NaN      NaN
# 1    NaN      NaN
# ...

# %%
df_combined_Tvshows = df_combined_Tvshows.drop(columns=['Rotten Tomatoes Rating (Percentage)'])

# %%
df_combined_Tvshows.shape
# Out:
# (5604, 13)

# %%
df_combined_Tvshows.head(100)
# Out:
#     season episode              name        year viewers Director rating  \
# 0      1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN
# 1      1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN
# 2      1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN
# 3      1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN
# 4      1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN
# ..     ...     ...               ...         ...     ...      ...    ...
# 95     7.0      13  The walking dead   3/12/2017   10.68      NaN    NaN
# 96     7.0      14  The walking dead   3/19/2017   10.32      NaN    NaN
# 97     7.0      15  The walking dead   3/26/2017   10.54      NaN    NaN
# 98     7.0      16  The walking dead    4/2/2017   11.31      NaN    NaN
# 99     8.0       1  The walking dead  10/22/2017   11.44      NaN    NaN
#
#    Votes  minutes  Image_url  Description  Genre  Runtime
# ...

# %%
df_combined_Tvshows.to_csv('Tvshows_Full.csv', index=False)

# %%
df_new_data = pd.read_csv("Tvshows_Full_Ready_1.csv", encoding='iso-8859-1')

# %%
df_new_data.head()
# Out:
#                 Tv_show  season  episode_number                       title  \
# 0  Clannad: After Story       1               1  Natsu no owari no sayonara
# 1  Clannad: After Story       1               2  Itsuwari no ai o sagashite
# 2  Clannad: After Story       1               3           Surechigau kokoro
# 3  Clannad: After Story       1               4      Anohi to onaji egao de
# 4  Clannad: After Story       1               5         Kimi no ita kisetsu
#
#         airdate  rating  total_votes
# 0   Oct 2, 2008     7.5          179
# 1   Oct 9, 2008     7.6          164
# 2  Oct 16, 2008     7.5          165
# 3  Oct 23, 2008     8.1          176
# 4  Oct 30, 2008     7.5          162

# %%
df_new_data = df_new_data.rename(columns={'title': 'names1','airdate': 'year','total_votes': 'Votes','episode_number': 'episode','Tv_show':'name'})

# %%
df_new_data.head()
# Out:
#                    name  season  episode                      names1  \
# 0  Clannad: After Story       1        1  Natsu no owari no sayonara
# 1  Clannad: After Story       1        2  Itsuwari no ai o sagashite
# 2  Clannad: After Story       1        3           Surechigau kokoro
# 3  Clannad: After Story       1        4      Anohi to onaji egao de
# 4  Clannad: After Story       1        5         Kimi no ita kisetsu
#
#            year  rating  Votes
# 0   Oct 2, 2008     7.5    179
# 1   Oct 9, 2008     7.6    164
# 2  Oct 16, 2008     7.5    165
# 3  Oct 23, 2008     8.1    176
# 4  Oct 30, 2008     7.5    162

# %%
df_new_data = df_new_data.drop(columns=['names1'])

# %%
df_new_data.head()
# Out:
#                    name  season  episode          year  rating  Votes
# 0  Clannad: After Story       1        1   Oct 2, 2008     7.5    179
# 1  Clannad: After Story       1        2   Oct 9, 2008     7.6    164
# 2  Clannad: After Story       1        3  Oct 16, 2008     7.5    165
# 3  Clannad: After Story       1        4  Oct 23, 2008     8.1    176
# 4  Clannad: After Story       1        5  Oct 30, 2008     7.5    162

# %%
df_combined_Tvshows.head()
# Out:
#    season episode              name        year viewers Director rating Votes  \
# 0     1.0       1  The walking dead  10/31/2010    5.35      NaN    NaN   NaN
# 1     1.0       2  The walking dead   11/7/2010    4.71      NaN    NaN   NaN
# 2     1.0       3  The walking dead  11/14/2010    5.07      NaN    NaN   NaN
# 3     1.0       4  The walking dead  11/21/2010    4.75      NaN    NaN   NaN
# 4     1.0       5  The walking dead  11/28/2010    5.56      NaN    NaN   NaN
#
#    minutes  Image_url  Description  Genre  Runtime
# 0      NaN        NaN          NaN    NaN      NaN
# 1      NaN        NaN          NaN    NaN      NaN
# 2      NaN        NaN          NaN    NaN      NaN
# 3      NaN        NaN          NaN    NaN      NaN
# 4      NaN        NaN          NaN    NaN      NaN

# %% [markdown]
# # merging them together

# %%
finla_merged_df = pd.concat([df_new_data, df_combined_Tvshows], ignore_index=True)

# %%
finla_merged_df.head()
# Out:
#                    name  season episode          year rating Votes viewers  \
# 0  Clannad: After Story     1.0       1   Oct 2, 2008    7.5   179     NaN
# 1  Clannad: After Story     1.0       2   Oct 9, 2008    7.6   164     NaN
# 2  Clannad: After Story     1.0       3  Oct 16, 2008    7.5   165     NaN
# 3  Clannad: After Story     1.0       4  Oct 23, 2008    8.1   176     NaN
# 4  Clannad: After Story     1.0       5  Oct 30, 2008    7.5   162     NaN
#
#   Director  minutes  Image_url  Description  Genre  Runtime
# 0      NaN      NaN        NaN          NaN    NaN      NaN
# 1      NaN      NaN        NaN          NaN    NaN      NaN
# 2      NaN      NaN        NaN          NaN    NaN      NaN
# 3      NaN      NaN        NaN          NaN    NaN      NaN
# 4      NaN      NaN        NaN          NaN    NaN      NaN

# %%
finla_merged_df.shape
# Out:
# (22057, 13)

# %%
finla_merged_df.to_csv('Final_tvshow_dataset_mf.csv', index=False)
